# %% [markdown]
# # LISTA DE PANDAS-2

# %% [markdown]
# **Importe as bibliotecas necessárias**
#
# **Importe os dados sobre as ações, que estão nos arquivos "carteira.csv" e "ativos.csv".**

# %%
##### SEU CODIGO COMECA AQUI #####
import pandas as pd 
df_carteiras= pd.read_csv("carteiras.csv", sep=",")
df_ativos= pd.read_csv("ativos.csv", sep=",")
df_ativos
df_ativos.set_index('data')
# Out:
#                  BPAC5       RAPT4       CMIG4       MELK3       DIRR3  \
# data
# 2021-12-31  100.000000  100.000000  100.000000  100.000000  100.000000
# 2022-01-03   96.153846   99.080037   98.245614   99.487179   95.594020
# 2022-01-04   94.423077   97.884085   98.169336   98.974359   92.210858
# 2022-01-05   86.730769   94.388224   95.041953   97.179487   85.995279
# 2022-01-06   84.574684   95.676173   92.982456   95.641026   84.107002
# ...                ...         ...         ...         ...         ...
# 2022-07-25  100.517499   95.537109  114.691627  100.249730   89.613702
# 2022-07-26   98.573253   95.731488  113.419631   99.191685   88.301882
# 2022-07-27  100.517499   98.161221  119.355612  103.159352   91.663421
# 2022-07-28  100.906348   98.452789  118.719614  105.010930   95.516892
# 2022-07-29  103.628292   97.675274  119.143613  104.746419   97.074678
#
#                  PLPL3       BPAN4       BRAP4  27.635.189/0001-45  \
# data
# 2021-12-31  100.000000  100.000000  100.000000               100.0
# 2022-01-03   95.692308   95.786517   98.639456               100.0
# 2022-01-04   93.846154   88.295880   99.559824               100.0
# 2022-01-05   86.461538   88.576779   99.799920               100.0
# 2022-01-06   84.923077   89.513109  102.641056               100.0
# ...                ...         ...         ...                 ...
# 2022-07-25   75.555017   63.874883   95.708112                 NaN
# 2022-07-26   74.903681   60.117537   95.581234                 NaN
# 2022-07-27   77.509027   60.493271   95.496649                 NaN
# 2022-07-28   81.417045   61.432608   96.765426                 NaN
# 2022-07-29   79.137367   62.371944   95.073723                 NaN
#
#             34.964.555/0001-75  ...       ITUB3       AURE3       WEGE3  \
# data                            ...
# 2021-12-31               100.0  ...  100.000000  100.000000  100.000000
# 2022-01-03               100.0  ...  101.613068  100.000000   97.089145
# 2022-01-04               100.0  ...  103.867641  100.000000   96.604002
# 2022-01-05               100.0  ...  101.770364  100.000000   91.510006
# 2022-01-06               100.0  ...  103.605481  100.000000   91.479685
# ...                        ...  ...         ...         ...         ...
# 2022-07-25                 NaN  ...  106.765198   88.046662   81.486868
# 2022-07-26                 NaN  ...  106.237963   88.353659   80.625224
# 2022-07-27                 NaN  ...  106.132516   88.108061   82.687014
# 2022-07-28                 NaN  ...  106.765198   85.959084   85.948951
# 2022-07-29                 NaN  ...  106.923369   87.125672   86.287453
#
#                  BRPR3       HBSA3       EVEN3       UGPA3       NEOE3  \
# data
# 2021-12-31  100.000000  100.000000  100.000000  100.000000  100.000000
# 2022-01-03   96.853625   98.260870   95.902883   97.111417   97.839506
# 2022-01-04   94.254446   90.144928   94.385432   93.466300   96.234568
# 2022-01-05   89.740082   85.217391   89.984825   90.990371   94.382716
# 2022-01-06   89.056088   83.768116   90.743551   89.683631   93.273261
# ...                ...         ...         ...         ...         ...
# 2022-07-25  116.000672   61.449275   70.561457   91.799236   96.090960
# 2022-07-26  116.000672   61.739130   72.534143   89.287138   96.479992
# 2022-07-27  120.153441   64.347826   75.720789   92.516978   99.203217
# 2022-07-28  120.015015   66.376812   80.273141   91.655688   97.387734
# 2022-07-29  116.554374   64.637681   81.031866   91.081494   96.026121
#
#                  TCSA3       ELET3
# data
# 2021-12-31  100.000000  100.000000
# 2022-01-03   94.182825   97.665370
# 2022-01-04   89.196676   95.570189
# 2022-01-05   81.994460   95.181084
# 2022-01-06   74.792244   95.031428
# ...                ...         ...
# 2022-07-25   62.880886  136.756247
# 2022-07-26   60.110803  136.146409
# 2022-07-27   63.434903  138.341827
# 2022-07-28   67.313019  138.585762
# 2022-07-29   65.650970  139.683471
#
# [146 rows x 131 columns]

# %% [markdown]
# **Exercício 1: Filtragem de dados**
#
# Filtre o Dataframe a partir de 5 ações, de modo que essas ações podem ser escolhidas pela sua preferência ou de forma aleatória. Após a filtragem, salve em uma nova variável.

# %%
##### SEU CODIGO COMECA AQUI #####

df_ativos = df_ativos.iloc[:,2:7]
df_ativos
# Out:
#           RAPT4       CMIG4       MELK3       DIRR3       PLPL3
# 0    100.000000  100.000000  100.000000  100.000000  100.000000
# 1     99.080037   98.245614   99.487179   95.594020   95.692308
# 2     97.884085   98.169336   98.974359   92.210858   93.846154
# 3     94.388224   95.041953   97.179487   85.995279   86.461538
# 4     95.676173   92.982456   95.641026   84.107002   84.923077
# ..          ...         ...         ...         ...         ...
# 141   95.537109  114.691627  100.249730   89.613702   75.555017
# 142   95.731488  113.419631   99.191685   88.301882   74.903681
# 143   98.161221  119.355612  103.159352   91.663421   77.509027
# 144   98.452789  118.719614  105.010930   95.516892   81.417045
# 145   97.675274  119.143613  104.746419   97.074678   79.137367
#
# [146 rows x 5 columns]

# %% [markdown]
# **Exercício 2: Retorno**
#
# Utilizando o Dataframe filtrado no exercício anterior, calcule o retorno diário dessas 5 ações. Para isso, utilize o método `pct_change`. Além disso, mude o nome das colunas para o nome da ação seguido de uma hashtag, por exemplo, 'BBAS3#'.
#
# salve um uma variável chamada `retorno`.

# %%
##### SEU CODIGO COMECA AQUI #####
variação = df_ativos.pct_change()

variação=variação.rename(columns={'CMIG4': 'CMIG4#'})
variação=variação.rename(columns={'RAPT4': 'RAPT4#'})
variação=variação.rename(columns={'MELK3': 'MELK3#'})
variação=variação.rename(columns={'DIRR3': 'DIRR3#'})
variação=variação.rename(columns={'PLPL3': 'PLPL3#'})

print(variação)
# Out:
#        RAPT4#    CMIG4#    MELK3#    DIRR3#    PLPL3#
# 0         NaN       NaN       NaN       NaN       NaN
# 1   -0.009200 -0.017544 -0.005128 -0.044060 -0.043077
# 2   -0.012071 -0.000776 -0.005155 -0.035391 -0.019293
# 3   -0.035714 -0.031857 -0.018135 -0.067406 -0.078689
# 4    0.013645 -0.021669 -0.015831 -0.021958 -0.017794
# ..        ...       ...       ...       ...       ...
# 141  0.010277  0.015962  0.010667 -0.038698 -0.068273
# 142  0.002035 -0.011091 -0.010554 -0.014639 -0.008621
# 143  0.025381  0.052336  0.040000  0.038069  0.034783
# 144  0.002970 -0.005329  0.017949  0.042039  0.050420
# 145 -0.007897  0.003571 -0.002519  0.016309 -0.028000
#
# [146 rows x 5 columns]

# %% [markdown]
# **Exercício 3: Ordenar**
#
# Utilizando o método `describe`, analise a média de retorno das ações. Após isso, organize os dados de tal modo que as ações sejam apresentadas de forma decrescente, isto é, a ação que teve a maior média de retorno para a  ação que teve a menor média de retorno.
#
#
#    *Lembre-se de definir o parâmetro 'ascending' e 'by'.*

# %%
##### SEU CODIGO COMECA AQUI #####

# %% [markdown]
# **Exercício 4: Manipulação**
#
# Para a ação que obteve a maior média de retonos no périodo apresentado, crie uma coluna chamada `acima_da_media_x`, sendo o 'x' o nome da ação. Sendo assim, essa coluna deve conter valores booleanos, `True` caso a ação esteja com o preço acima da sua média e `False` caso o preço da ação seja menor ou igual a média. Feito isso, printe apenas os dados que são iguais a `True`.
#
# *Dessa forma, poderemos saber em quais dias que a ação obteve um retorno maior que a sua média*

# %%
##### SEU CODIGO COMECA AQUI #####

# %% [markdown]
# **Exercício 5: Proporção**
#
# Após descobrir em quais dias que a ação teve um retorno maior que a sua média, calcule qual foi a proporção em que isso aconteceu, ou seja, a proporção de dias que esteve acima da média em relação ao total de dias.
#
# *printe essa proporção da seguinte forma: 'A proporção de dias acima da média foi de X%', sendo 'X' a proporção. Arredonde em duas casa decimais o valor encontrado*

# %%
##### SEU CODIGO COMECA AQUI #####
acima_da_media = df[df["retornos"] > np.mean(df["retornos"])]
prop = len(acima_da_media)/len(df["retornos"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 ##### SEU CODIGO COMECA AQUI #####
# ----> 2 acima_da_media = df[df["retornos"] > np.mean(df["retornos"])]
#       3 prop = len(acima_da_media)/len(df["retornos"])
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Exercício 6: Junção**
#
# Por fim, faça a união **total** do dataframe contendo cinco primeiras ações escolhidas  inicialmente (no ex. 1) com o dataframe contendo os retornos dessas ações (criado no ex.2). Espera-se um único dataframe como resposta.

# %%
##### SEU CODIGO COMECA AQUI #####
lista = [1,2,3,7,8]
acima = lista[lista > mean(lista)]
prop = len(acima)/len(lista)
print(prop)
